# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt

"""* Step 1. Inptu tensor 와 Target tensor 준비(훈련데이터)"""

# label 데이터의 각 value 에 해당하는 class name 정보
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()


"""* Step 2. 데이터의 전처리 """

train_images = train_images.reshape(60000,28*28)
test_images = test_images.reshape((test_images.shape[0], test_images.shape[1]*test_images.shape[2]))



train_images = train_images/255.0
test_images = test_images/255.0


train_labels = tf.keras.utils.to_categorical(train_labels, 10)
test_labels = tf.keras.utils.to_categorical(test_labels, 10)


"""* Step 3. DNN(MLP) 모델 디자인"""

from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers

model = models.Sequential()
model.add(layers.Dense(units=256, activation = 'relu', input_shape=(28*28,)))
model.add(layers.Dense(units=10, activation = 'softmax'))

          
"""* Step 4. 모델의 학습 정보 설정"""


model.compile(optimizer = 'RMSprop', loss = 'categorical_crossentropy', metrics=['accuracy'])

"""* Step 5. 모델에 input, target 데이터 연결 후 학습"""


model.fit(x=train_images, y=train_labels, epochs=30, batch_size=128, validation_split = 0.2)

model.save('my_model.h5')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.5886 - accuracy: 0.7924 - val_loss: 0.4402 - val_accuracy: 0.8479
# Epoch 2/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.4055 - accuracy: 0.8535 - val_loss: 0.3734 - val_accuracy: 0.8664
# Epoch 3/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.3568 - accuracy: 0.8697 - val_loss: 0.3863 - val_accuracy: 0.8611
# Epoch 4/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3271 - accuracy: 0.8794 - val_loss: 0.3510 - val_accuracy: 0.8745
# Epoch 5/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.3065 - accuracy: 0.8876 - val_loss: 0.3322 - val_accuracy: 0.8825
# Epoch 6/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2905 - accuracy: 0.8936 - val_loss: 0.3376 - val_accuracy: 0.8815
# Epoch 7/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2751 - accuracy: 0.8984 - val_loss: 0.3338 - val_accuracy: 0.8857
# Epoch 8/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2648 - accuracy: 0.9007 - val_loss: 0.3373 - val_accuracy: 0.8784
# Epoch 9/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2522 - accuracy: 0.9061 - val_loss: 0.3099 - val_accuracy: 0.8923
# Epoch 10/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2416 - accuracy: 0.9102 - val_loss: 0.3144 - val_accuracy: 0.8913
# Epoch 11/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.2347 - accuracy: 0.9134 - val_loss: 0.3310 - val_accuracy: 0.8864
# Epoch 12/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2235 - accuracy: 0.9179 - val_loss: 0.3183 - val_accuracy: 0.8925
# Epoch 13/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2192 - accuracy: 0.9200 - val_loss: 0.3300 - val_accuracy: 0.8920
# Epoch 14/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2120 - accuracy: 0.9214 - val_loss: 0.3264 - val_accuracy: 0.8937
# Epoch 15/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2035 - accuracy: 0.9245 - val_loss: 0.3310 - val_accuracy: 0.8893
# Epoch 16/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1959 - accuracy: 0.9280 - val_loss: 0.3353 - val_accuracy: 0.8944
# Epoch 17/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1916 - accuracy: 0.9290 - val_loss: 0.3245 - val_accuracy: 0.8963
# Epoch 18/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1839 - accuracy: 0.9322 - val_loss: 0.3300 - val_accuracy: 0.8947
# Epoch 19/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1790 - accuracy: 0.9327 - val_loss: 0.3695 - val_accuracy: 0.8859
# Epoch 20/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1752 - accuracy: 0.9359 - val_loss: 0.3655 - val_accuracy: 0.8935
# Epoch 21/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1712 - accuracy: 0.9373 - val_loss: 0.3545 - val_accuracy: 0.8901
# Epoch 22/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1658 - accuracy: 0.9386 - val_loss: 0.3653 - val_accuracy: 0.8918
# Epoch 23/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1605 - accuracy: 0.9403 - val_loss: 0.3472 - val_accuracy: 0.8982
# Epoch 24/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1573 - accuracy: 0.9408 - val_loss: 0.3507 - val_accuracy: 0.8963
# Epoch 25/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1519 - accuracy: 0.9442 - val_loss: 0.3761 - val_accuracy: 0.8920
# Epoch 26/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1478 - accuracy: 0.9452 - val_loss: 0.3621 - val_accuracy: 0.8975
# Epoch 27/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1455 - accuracy: 0.9457 - val_loss: 0.4257 - val_accuracy: 0.8809
# Epoch 28/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1413 - accuracy: 0.9475 - val_loss: 0.3936 - val_accuracy: 0.8921
# Epoch 29/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1366 - accuracy: 0.9482 - val_loss: 0.3923 - val_accuracy: 0.8932
# Epoch 30/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1344 - accuracy: 0.9500 - val_loss: 0.4139 - val_accuracy: 0.8908
